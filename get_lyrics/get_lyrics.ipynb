# %%
from dotenv import load_dotenv
# import requests
import lyricsgenius as lg
import pandas as pd
import numpy as np
import re
import string
import os

# %%
client_id = os.getenv('GENIUS_CLIENT_ID')
client_secret = os.getenv('GENIUS_CLIENT_SECRET')
access_token = os.getenv('GENIUS_ACCESS_TOKEN')

# %%
spot_df = pd.read_csv('track_artists.csv')
names = np.array(spot_df['name'])
artists = np.array(spot_df['artists_names'])

# %%
genius = lg.Genius(access_token=access_token)

# %%
def get_spot_lyrics(row):
        song_name = row['name']
        artist_name = row['artists_names']
        # for names e.g. XXX Song - Live at XXX
        song_name = song_name.split(' - ',1)[0]
        # for names e.g. XXX (feat YYY)
        song_name = re.sub(r"[\(].*?[\)]", "", song_name)
        artist_name = re.sub(r"[\(].*?[\)]", "", artist_name)
        # for removing all punctuation
        song_name = song_name.translate(str.maketrans('', '', string.punctuation))
        artist_name = artist_name.translate(str.maketrans('', '', string.punctuation))
    
        try:
            song = genius.search_song(song_name, artist= artist_name, get_full_info= False)
        except:
            return ''
            
        if song:
            return song.lyrics.split(']',1)[-1]
        return ''

# %%
import dask.dataframe as dd

spot_dask = dd.from_pandas(spot_df, npartitions= 128)
# res = spot_dask.map_partitions(get_spot_lyrics,meta=(None, 'string'))
res = spot_dask.apply(get_spot_lyrics, axis =1, meta = (None, 'string'))

# %%
res_out = res.compute()
# Out:
# Searching for "Walk on by " by Noosa...
# Searching for "The Safety Dance" by Men Without Hats...
# Searching for "Try Me" by DeJ Loaf...
# Searching for "Way Up " by Floduxe...
# Searching for "Coastin feat K Flay" by Zion I...
# Searching for "Human Being" by Zion I...
# Searching for "Whirlpool" by Sea Wolf...
# Searching for "Fantasy" by Alina Baraz...
# Searching for "Saskatoon" by Data Romance...
# Searching for "Party  Bullshit In The USA" by DJ Crazy J Rodriguez...
# Searching for "Religion" by Tongues...
# Searching for "Call Me Crazy" by PJ Simas...
# Searching for "Pretty Wings" by Zak Waters...
# Searching for "Idle Hands" by EXGF...
# Searching for "Wait a Minute" by Safakash...
# Searching for "Whiskey My Love" by Kalob Griffin Band...
# No results found for: 'Saskatoon Data Romance'
# Searching for "Pocket Full Of Gold" by American Authors...
# No results found for: 'Wait a Minute Safakash'
# Searching for "Waiting For You" by Grizfolk...
# Done.
# Searching for "Endless Summer" by Grizfolk...
# Done.
# Searching for "Odds Are" by Barenaked Ladies...
# Done.
# Done.
# Done.
# Searching for "Those Nights" by Bastille...
# Searching for "Salvation" by The Strumbellas...
# Searching for "Straight Jacket" by Bay Ledges...
# Done.
# Searching for "Hymnals" by Grizfolk...
# Done.
# Searching for "Turning Me Up " by Issam Alnajjar...
# Done.
# Searching for "Problems" by Don Diablo...
# Done.
# Searching for "Somebody To Love" by Axel Black  White...
# Done.
# Searching for "Closer " by Sonny Fodera...
# Done.
# Searching for "Loop de Loop" by RV...
# Done.
# Searching for "I Dont Wanna Talk " by Glass Animals...
# Done.
# Done.
# Searching for "Put Me in the Ground " by Daniel Nunnelee...
# Searching for "pictures feat Kacey Musgraves" by Judah  the Lion...
# Done.
# Searching for "Remind You" by FRENSHIP...
# Done.
# Searching for "As Long as Youre Here" by Telehope...
# Done.
# Searching for "where we are " by The Lumineers...
# Done.
# Searching for "Everythings Gonna Be Alright" by David Lee Murphy...
# Done.
# Searching for "PARADISE TO ME" by Niko Moon...
# Done.
# Searching for "Make Me Wanna" by Thomas Rhett...
# Done.
# Searching for "Castaway" by Zac Brown Band...
# Done.
# Searching for "Where Its At" by Dustin Lynch...
# Done.
# Searching for "Good Girl" by Dustin Lynch...
# Done.
# Searching for "Hey Leroy Your Mamas Callin You" by Various Artists...
# Done.
# Searching for "Sun Daze" by Florida Georgia Line...
# Done.
# Done.
# Searching for "Rumor" by Lee Brice...
# Searching for "Gonna" by Blake Shelton...
# Done.
# Done.
# Searching for "Islands In the Stream" by Dolly Parton...
# Searching for "Mine Again " by Dalton Domino...
# Done.
# Searching for "All To Myself" by Dan  Shay...
# Done.
# Searching for "Beer Can in a Truck Bed" by Old Dominion...
# Done.
# Searching for "Good Vibes Tonight" by UB40...
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.

# %%
spot_df['lyrics'] = res_out
spot_df.head()
# Out:
#                               track_uri          name artists_names  \
# 0  spotify:track:3v6sBj3swihU8pXQQHhDZo       Way Up        Floduxe
# 1  spotify:track:7KCWmFdw0TzoJbKtqRRzJO       Fantasy   Alina Baraz
# 2  spotify:track:2CY92qejUrhyPUASawNVRr        Try Me      DeJ Loaf
# 3  spotify:track:11BPfwVbB7vok7KfjBeW4k   Walk on by          Noosa
# 4  spotify:track:3yUJKPsjvThlcQWTS9ttYx  Pretty Wings    Zak Waters
#
#    popularity album_type                                playlist_uris  \
# 0           0     single  ['spotify:playlist:5JJZvA3VR9RZ5XIr0reWiM']
# 1          33      album  ['spotify:playlist:5JJZvA3VR9RZ5XIr0reWiM']
# 2          52     single  ['spotify:playlist:5JJZvA3VR9RZ5XIr0reWiM']
# 3           0     single  ['spotify:playlist:5JJZvA3VR9RZ5XIr0reWiM']
# 4           0     single  ['spotify:playlist:5JJZvA3VR9RZ5XIr0reWiM']
#
#    danceability  energy  key  loudness  ...  liveness  valence    tempo  \
# 0         0.611   0.614  5.0    -8.815  ...    0.7530    0.520  128.050
# 1         0.638   0.781  4.0    -6.848  ...    0.3490    0.250  122.985
# 2         0.560   0.810  0.0    -8.029  ...    0.2410    0.247  170.044
# 3         0.525   0.699  9.0    -4.571  ...    0.0888    0.199   92.011
# 4         0.367   0.771  9.0    -5.863  ...    0.0965    0.163  115.917
#
#    duration_ms  time_signature  \
# 0     195000.0             4.0
# 1     194641.0             4.0
# 2     217573.0             4.0
# 3     443478.0             4.0
# 4     225862.0             4.0
#
#                                       artists_genres  release_year  \
# 0                                          ['indie']          2015
# 1  ['future', 'etherpop', 'bass', 'chillstep', 'r...          2015
# 2  ['queen', 'trap', 'detroit', 'hip', 'r&b', 'po...          2014
# 3                       ['pop', 'shimmer', 'shiver']          2014
# 4                ['poptimism', 'la', 'indie', 'pop']          2014
#
#    artists_mean_popularities  artists_mean_followers  \
# 0                        9.0                   765.0
# 1                       62.0                711030.5
# 2                       65.0               1544981.0
# 3                       32.0                 18241.0
# 4                       34.5                 11940.0
#
#                                               lyrics
# 0
# I just poured up a 4 you know what I'm sayin'...
# 1
# So you say you wanna get away
# We don't need a...
# 2
# Let a nigga try me, try me
# I'm a get his whol...
# 3  2 ContributorsWalk On By LyricsRun when the rh...
# 4  " ft. Björk
# Tessa Violet - "You Are Not My Fri...
#
# [5 rows x 24 columns]

# %%
def process_lyrics(row):
    lyrics = row['lyrics']
    if len(lyrics) == 0:
        lyrics = row['name'] + row['artists_names']
    # remove words in brackets and square brackets
    lyrics = re.sub("[\(\[].*?[\)\]]", "", lyrics)
    # remove line breaks
    lyrics= lyrics.replace("\n", " ")
    # remove all punctuation
    lyrics = lyrics.translate(str.maketrans('', '', string.punctuation))
    # lower case
    return lyrics.lower()

# %%
import fasttext
model = fasttext.load_model('lid.176.bin')
spot_df['lyrics'] = spot_df.apply(lambda x : process_lyrics(x), axis = 1)
is_eng = spot_df['lyrics'].apply(lambda x : model.predict(x)[0][0] == '__label__en')
spot_df = spot_df[is_eng].reset_index(drop = True)
spot_df.shape
# Out:
# (41, 24)

# %%
spot_df.to_json('spot_lyrics.json')
